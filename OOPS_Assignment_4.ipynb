# %% [markdown]
# 1. What is Object-Oriented Programming (OOP)?
# -  Object-Oriented Programming (OOP) is a programming paradigm that organizes code into objects, which represent real-world entities. These objects bundle data (attributes/variables) and behavior (methods/functions) together, making programs easier to understand, maintain, and scale.
#
# Key Concepts of OOP
#
# Class
#
# -A blueprint/template for creating objects.
#
# -Defines the attributes (variables) and behaviors (methods).
#
# Example: Car class.
#
# Object
#
# - An instance of a class.
#
# - Each object has its own data but shares the structure of the class.
#
# Example: car1 and car2 are objects of class Car.
#
# Encapsulation
#
# - Wrapping data and methods together inside a class.
#
# - Helps in data hiding (using private/protected variables).
#
# Abstraction
#
# - Hiding unnecessary details and showing only essential features.
#
# Example: You drive a car without worrying about how the engine works.
#
# Inheritance
#
# - One class can inherit properties and methods from another.
#
# - Promotes code reusability.
#
# Example: ElectricCar inherits from Car.
#
# Polymorphism
#
# - Ability to use the same method name but perform different actions depending on the object.
#
# Example: A method drive() behaves differently for Car and Bike.
#
# 2. What is a class in OOP?
# -  In Object-Oriented Programming (OOP), a class is a blueprint or template used to create objects.
#
# It defines the attributes (data/variables) and methods (functions/behaviors) that the created objects will have.
#
# Features of a Class:
#
# - Blueprint – It does not represent a real object itself but tells how objects will look and behave.
#
# - Attributes (Data members) – Variables inside the class that hold data.
#
# - Methods (Member functions) – Functions inside the class that define behavior.
#
# - Instantiation – When you create an object from a class, it’s called instantiating a class.
#
# 3. What is an object in OOP?
# -  In Object-Oriented Programming (OOP), an object is an instance of a class.
# It is the real-world entity that is created based on the blueprint (class).
#
# Features of an Object:
#
# - Instance of a Class – Objects are created from classes.
#
# - Has State (Attributes/Properties) – Stores data (like brand, model, color).
#
# - Has Behavior (Methods/Functions) – Performs actions (like drive, eat, bark).
#
# - Unique Identity – Each object has its own memory location and can hold different data even if created from the same class.
#
# 4. What is the difference between abstraction and encapsulation.
# -  Difference Between Abstraction and Encapsulatio
#
# Abstraction
#
# - Hides implementation details, shows only essential features.
#
# - Focuses on what an object does.
#
# - Achieved using abstract classes and interfaces.
#
# - Example: You drive a car without knowing how the engine works.
#
# 5. What are dunder methods in Python?
# -  In Python, dunder methods (also called magic methods or special methods) are built-in methods that have double underscores before and after their names (e.g., __init__, __str__, __len__).
#
# They let you customize the behavior of objects and make classes behave like built-in types.
#
# Key Points:
#
# - Dunder = Double Underscore ( __method__ ).
#
# - They are automatically called by Python in certain situations.
#
# - They allow operator overloading, object initialization, string representation, etc.
#
# 6. Explain the concept of inheritance in OOP.
# -  Inheritance is the process by which one class (child/derived class) can acquire the properties and behaviors (attributes and methods) of another class (parent/base class).
#
# It promotes code reusability and helps in building a relationship between classes.
#
# Key Points about Inheritance
#
# - Parent/Base Class → The class whose properties are inherited.
#
# - Child/Derived Class → The class that inherits from the parent.
#
# - Child can reuse, extend, or override the parent’s functionality.
#
# - Improves code reusability and avoids duplication.
#
# 7. What is polymorphism in OOP.
# -  The word Polymorphism comes from Greek:
#
# Poly = many
#
# Morph = forms
#
#  In OOP, Polymorphism means the same function or operator can behave differently depending on the object or data type.
#
#  Key Ideas
#
# - One name, many forms (same method works differently on different classes).
#
# - Increases flexibility and reusability.
#
# - Achieved mainly through:
#
# Method Overriding (runtime polymorphism)
#
# Method Overloading (compile-time polymorphism — not directly in Python but simulated using default args or *args).
#
# Operator Overloading (using dunder methods like __add__, __len__, etc.).
#
# 8. How is encapsulation achieved in Python?
# -  Encapsulation in Python
#
# Encapsulation means wrapping data (variables) and methods (functions) into a single unit (class) and restricting direct access to some of the object’s attributes.
#
# In Python, encapsulation is achieved using access modifiers:
#
# 1. Public Members
#
# - Accessible everywhere.
#
# - By default, all attributes and methods in Python are public.
#
# 2. Private Members (Double underscore __)
#
# - Indicated by double underscores (__variable).
#
# - Python name-mangles it → variable is stored as _ClassName__variable.
#
# - Not accessible directly, only via methods.
#
# 3. Protected Members (Single underscore _)
#
# - Indicated by a single underscore (_variable).
#
# - Should not be accessed directly outside the class (but technically possible).
#
# - It's more of a convention, not strict enforcement.
#
# 9. What is a constructor in Python?
# -  Constructor in Python
#
# - A constructor is a special method in Python used to initialize an object’s state when it is created.
#
# - In Python, the constructor method is always named __init__.
#
# - It is automatically called when an object of a class is created.
#
# - Used to set initial values for the object’s attributes.
#
# 10. What are class and static methods in Python?
# -   1.    Class Method (@classmethod)
#
# - A method that belongs to the class, not the object.
#
# - It takes cls (class itself) as the first argument instead of self.
#
# - Can access and modify class-level variables.
#
# - Declared using the @classmethod decorator.
#
# -    2. Static Method (@staticmethod)
#
# - A method that does not depend on the class or instance.
#
# - It doesn’t take self or cls as the first argument.
#
# - Used for utility/helper functions that are related to the class but don’t need access to class/instance variables.
#
# - Declared using the @staticmethod decorator.
#
# 11. What is method overloading in Python?
# -   Method Overloading means having multiple methods with the same name but different parameters (number or type).
#
# In Java/C++, this is directly supported.
#
# In Python, true method overloading is not supported because:
#
# If you define multiple methods with the same name in a class, the last one overrides the previous ones.
#
# Since Python doesn’t support it directly, we achieve it using:
#
# - Default arguments
#
# - Variable-length arguments (*args and **kwargs)
#
#
# Python does not support traditional method overloading like Java, but we can achieve similar behavior using default parameters or *args/**kwargs to handle different numbers of arguments.
#
# class Math:
#     def add(self, *args):
#         return sum(args)
#
# m = Math()
# print(m.add(2, 3))           # 5
# print(m.add(2, 3, 4))        # 9
# print(m.add(1, 2, 3, 4, 5))  # 15
#
# 12. What is method overriding in OOP.
# -   Method Overriding happens when a child (derived) class provides its own implementation of a method that already exists in the parent (base) class.
#
# The method in the child class must have the same name, parameters, and return type as the parent method.
#
# It allows the child class to customize or completely replace the parent class’s behavior.
#
# 13. What is a property decorator in Python?
# -   The @property decorator in Python is used to make a method act like an attribute.
#
# - It lets you access methods as if they were variables (without parentheses ()).
#
# - Commonly used to implement getters, setters, and deleters in a clean way.
#
# - Helps in encapsulation (control access to private variables).
#
# 14. Why is polymorphism important in OOP?
# -   Polymorphism is important because it makes programs more flexible, reusable, and easier to maintain.
#
# Here’s why:
#
# - Code Reusability
#
# You can write generic code that works with different object types.
#
# Example: A function can call speak() on Dog, Cat, or Bird objects without caring about their class.
#
# - Flexibility & Extensibility
#
# New classes can be added without changing existing code.
#
# Example: Add a Cow class with its own speak(), and existing code still works.
#
# - Cleaner & Readable Code
#
# Avoids writing multiple if-else or switch statements for different object types.
#
# Instead, objects decide their behavior at runtime.
# - Supports Runtime Polymorphism (Method Overriding)
#
# Helps implement dynamic behavior depending on the object.
#
# - Encourages Interface Design
#
# By using abstract classes or interfaces, polymorphism ensures different classes follow the same contract while having different implementations.
#
# Polymorphism is important in OOP because it allows the same interface to be used with different types of objects, making code more flexible, reusable, and easier to extend without modification.
#
# 15. What is an abstract class in Python?
# -   An abstract class is a class that cannot be instantiated directly.
#
# - It is meant to act as a blueprint for other classes.
#
# - It can contain:
#
# Abstract methods (methods declared but not implemented).
#
# Concrete methods (normal methods with implementation).
#
# - Child classes that inherit from an abstract class must provide implementations for all its abstract methods.
#
# In Python, abstract classes are created using the abc (Abstract Base Class) module.
#
# from abc import ABC, abstractmethod
#
# class Animal(ABC):   # Abstract class
#     @abstractmethod
#     def sound(self):  # Abstract method (no implementation)
#         pass
#
#     def sleep(self):  # Normal method (with implementation)
#         print("Sleeping...")
#
# class Dog(Animal):    # Child class
#     def sound(self):  # Must implement abstract method
#         return "Barks"
#
# class Cat(Animal):
#     def sound(self):
#         return "Meows"
#
# # a = Animal()  #  Error: Can't instantiate abstract class
# d = Dog()
# c = Cat()
#
# print(d.sound())  # Barks
# print(c.sound())  # Meows
# d.sleep()         # Sleeping...
#
# 16.  What are the advantages of OOP?
# -    Advantages of Object-Oriented Programming (OOP)
#
# 1. Modularity (Code Organization)
#
# Code is divided into classes and objects, making it more organized and easier to understand.
#
# 2. Reusability
#
# Classes and methods can be reused in other programs without rewriting code.
#
# 3. Encapsulation (Data Hiding)
#
# Data is protected from unauthorized access by using access modifiers (like private/protected).
#
# 4. Abstraction (Hiding Complexity)
#
# Focus on what an object does rather than how it does it.
#
# Example: You call .sort() without knowing the sorting algorithm internally.
#
# 5. Inheritance (Code Reusability + Extensibility)
#
# A new class can inherit attributes and methods from an existing class.
#
# Saves time and avoids duplication.
#
# 6. Polymorphism (Flexibility)
#
# The same interface can be used with different objects.
#
# Example: len() works for strings, lists, tuples, etc.
#
# 7. Maintainability
#
# Because of modularity and reusability, fixing and updating code is easier.
#
# 8. Scalability
#
# Large projects can be built more efficiently as OOP naturally supports teamwork (different developers can work on different classes).
#
# 9. Improved Productivity
#
# Reusable and maintainable code increases development speed.
#
# 10. Real-world Modeling
#
# OOP is close to how we see the real world (objects with attributes and behaviors).
#
# Makes system design more intuitiv
#
# OOP provides modularity, reusability, encapsulation, abstraction, inheritance, and polymorphism — making programs more secure, maintainable, and scalable while modeling real-world problems effectively.
#
# 17.  What is the difference between a class variable and an instance variable?
# -   Class Variable
#
# - Definition: A variable that is defined inside a class but outside any methods.
#
# - Scope: Belongs to the class itself, not individual objects.
#
# - Shared Value: All objects (instances) of that class share the same value.
#
# - Modification:
#
# If you modify a class variable using the class name, the change reflects for all objects.
#
# If you modify it using self.variable, it creates a new instance variable instead (shadowing the class variable for that object only).
#
#
# - Instance Variable
#
# - Definition: A variable that is defined inside the constructor (__init__) or other methods using self.
#
# - Scope: Belongs to a specific object (instance).
#
# - Unique Value: Each object has its own copy of the instance variable.
#
# - Modification: Changing an instance variable affects only that object, not others.
#
# 18. What is multiple inheritance in Python?
# -  Multiple Inheritance means a class can inherit from more than one parent class.
#
# This allows the child class to reuse methods and attributes from multiple classes.
#
# Python supports multiple inheritance directly (unlike some languages like Java).
#
# Example:- class Father:
#     def skills(self):
#         print("Father: Gardening, Driving")
#
# class Mother:
#     def skills(self):
#         print("Mother: Cooking, Painting")
#
# # Child inherits from both Father and Mother
# class Child(Father, Mother):
#     def skills(self):
#         # Call both parent methods using super() and class names
#         Father.skills(self)
#         Mother.skills(self)
#         print("Child: Dancing, Coding")
#
# # Create object
# c = Child()
# c.skills()
#
# 19. Explain the purpose of ‘’__str__’ and ‘__repr__’ ‘ methods in Python.
#   1.  __str__
#
# - Purpose: Human-readable representation of the object.
#
# - Called when you use str(object) or print(object).
#
# - Meant for end users (more friendly output).
#
#   2.  __repr__
#
# - Purpose: Unambiguous / Developer-readable representation of the object.
#
# - Called when you use repr(object) or just type the object name in the Python shell.
#
# - Meant for debugging and developers. Ideally, __repr__ should return a string that, if possible, can be used to recreate the object.
#
# 20. What is the significance of the ‘super()’ function in Python?
# -   The super() function in Python is used to call methods from a parent (superclass) inside a child (subclass).
#
# - It is most commonly used inside the constructor (__init__) to call the parent constructor.
#
# - It avoids the need to explicitly write the parent class name.
#
# - It supports multiple inheritance by following Python’s Method Resolution Order (MRO).
#
# 21. What is the significance of the __del__ method in Python?
# -   __del__ is a destructor method in Python.
#
# - It is called automatically when an object is about to be destroyed (i.e., when it is garbage collected).
#
# - Its main purpose is to release resources (like closing files, database connections, or network sockets) before the object is removed from memory.
#
# 22.  What is the difference between @staticmethod and @classmethod in Python?
# -   A static method belongs to the class, but it does not depend on either:
#
# the instance (self) OR
#
# the class (cls).
#
# - It behaves like a normal function, just placed inside the class for logical grouping.
#
# - Used for utility/helper methods.
#
# Example:
# class MathUtils:
#     @staticmethod
#     def add(a, b):
#         return a + b
#
# print(MathUtils.add(10, 20))  # 30
#
# Here:
#
# No self → no instance used.
#
# No cls → no class variables used.
#
# Just a simple function inside a class for organization.
#
#
# - A class method takes cls as its first parameter.
#
# - cls represents the class itself (not the object).
#
# - It can access and modify class-level variables shared by all objects.
#
# - Used to write factory methods or update class state.
#
#  Example:
# class Student:
#     school = "ABC School"   # Class variable
#
#     def __init__(self, name):
#         self.name = name    # Instance variable
#
#     @classmethod
#     def change_school(cls, new_school):
#         cls.school = new_school
#
# # Before change
# print(Student.school)   # ABC School
#
# Student.change_school("XYZ School")  # modifies class variable
#
# print(Student.school)   # XYZ School
#
# 23. How does polymorphism work in Python with inheritance?
# -   Polymorphism means “many forms” — the same method name can behave differently depending on the object that calls it.
#
# When inheritance is used, polymorphism allows child classes to provide their own implementation of methods that are defined in the parent class.
#
# Example:- class Animal:
#     def make_sound(self):
#         return "Some generic sound"
#
# class Dog(Animal):
#     def make_sound(self):
#         return "Bark"
#
# class Cat(Animal):
#     def make_sound(self):
#         return "Meow"
#
# # Polymorphism in action
# animals = [Dog(), Cat(), Animal()]
#
# for a in animals:
#     print(a.make_sound())
#
# 24. What is method chaining in Python OOP?
# -   Method chaining means calling multiple methods sequentially on the same object in a single line of code.
# This works when each method returns the object itself (self), so that the next method can be called on it.
#
# Example:- calc = Calculator()
# result = calc.add(10).subtract(2).multiply(5)
#
# print(result.value)  # 40
#
#
# 25. What is the purpose of the __call__ method in Python?
# -   It makes instances of a class callable like functions.
#
# When you define __call__ inside a class, you can use the object followed by parentheses () to execute code.
#
# Example:-  class Greeter:
#     def __init__(self, name):
#         self.name = name
#
#     def __call__(self):
#         return f"Hello, {self.name}!"
#
# # Create an object
# greet = Greeter("Shivani")
#
# # Call the object like a function
# print(greet())  # Output: Hello, Shivani!

# %% [markdown]
# Practical Questions

# %%
# Parent class
class Animal:
    def speak(self):
        print("This animal makes a sound.")

# Child class
class Dog(Animal):
    # Override the speak() method
    def speak(self):
        print("Bark!")

# Example usage
a = Animal()
a.speak()

d = Dog()
d.speak()
# Out:
# This animal makes a sound.
# Bark!

# %%
#2 Write a program to create an abstract class Shape with a method area(). Derive classes Circle and Rectangle from it and implement the area() method in both.
from abc import ABC, abstractmethod
import math

# Abstract class
class Shape(ABC):
    @abstractmethod
    def area(self):
        pass  # Must be implemented in child classes

# Derived class: Circle
class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def area(self):
        return math.pi * (self.radius ** 2)

# Derived class: Rectangle
class Rectangle(Shape):
    def __init__(self, length, width):
        self.length = length
        self.width = width

    def area(self):
        return self.length * self.width

# Example usage
shapes = [
    Circle(5),
    Rectangle(4, 6)
]

for shape in shapes:
    print(f"Area: {shape.area()}")
# Out:
# Area: 78.53981633974483
# Area: 24

# %%
#3  Implement a multi-level inheritance scenario where a class Vehicle has an attribute type. Derive a class Car and further derive a class ElectricCar that adds a battery attribute.
# Base class
class Vehicle:
    def __init__(self, v_type):
        self.type = v_type

    def show_info(self):
        print(f"Vehicle Type: {self.type}")

# Derived class (inherits from Vehicle)
class Car(Vehicle):
    def __init__(self, v_type, brand):
        super().__init__(v_type)   # Call Vehicle constructor
        self.brand = brand

    def show_info(self):
        super().show_info()
        print(f"Brand: {self.brand}")

# Further derived class (inherits from Car)
class ElectricCar(Car):
    def __init__(self, v_type, brand, battery_capacity):
        super().__init__(v_type, brand)  # Call Car constructor
        self.battery_capacity = battery_capacity

    def show_info(self):
        super().show_info()
        print(f"Battery Capacity: {self.battery_capacity} kWh")

# Example usage
e_car = ElectricCar("Four Wheeler", "Tesla", 75)
e_car.show_info()
# Out:
# Vehicle Type: Four Wheeler
# Brand: Tesla
# Battery Capacity: 75 kWh

# %%
#4  Demonstrate polymorphism by creating a base class Bird with a method fly(). Create two derived classes Sparrow and Penguin that override the fly() method.
# Base class
class Bird:
    def fly(self):
        print("This bird can fly in some way.")

# Derived class 1
class Sparrow(Bird):
    def fly(self):
        print("Sparrow flies high in the sky!")

# Derived class 2
class Penguin(Bird):
    def fly(self):
        print("Penguins cannot fly, but they swim very well!")

# Demonstrating polymorphism
birds = [Sparrow(), Penguin()]

for bird in birds:
    bird.fly()
# Out:
# Sparrow flies high in the sky!
# Penguins cannot fly, but they swim very well!

# %%
#5 . Write a program to demonstrate encapsulation by creating a class BankAccount with private attributes balance and methods to deposit, withdraw, and check balance.
class BankAccount:
    def __init__(self, initial_balance=0):
        self.__balance = initial_balance   # private attribute

    # Method to deposit money
    def deposit(self, amount):
        if amount > 0:
            self.__balance += amount
            print(f"Deposited: {amount}")
        else:
            print("Deposit amount must be positive.")

    # Method to withdraw money
    def withdraw(self, amount):
        if 0 < amount <= self.__balance:
            self.__balance -= amount
            print(f"Withdrew: {amount}")
        else:
            print("Insufficient balance or invalid amount.")

    # Method to check balance
    def get_balance(self):
        return self.__balance

# Example usage
account = BankAccount(1000)

account.deposit(500)     # Deposited: 500
account.withdraw(300)    # Withdrew: 300
print("Current Balance:", account.get_balance())  # Current Balance:_
# Out:
# Deposited: 500
# Withdrew: 300
# Current Balance: 1200

# %%
#6 Demonstrate runtime polymorphism using a method play() in a base class Instrument. Derive classes Guitar and Piano that implement their own version of play().
# Base class
class Instrument:
    def play(self):
        print("This instrument makes some sound.")

# Derived class: Guitar
class Guitar(Instrument):
    def play(self):
        print("Strumming the guitar 🎸")

# Derived class: Piano
class Piano(Instrument):
    def play(self):
        print("Playing the piano 🎹")

# Demonstrating runtime polymorphism
instruments = [Guitar(), Piano()]

for inst in instruments:
    inst.play()
# Out:
# Strumming the guitar 🎸
# Playing the piano 🎹

# %%
#7 Create a class MathOperations with a class method add_numbers() to add two numbers and a static method subtract_numbers() to subtract two numbers.
class MathOperations:

    # Class method
    @classmethod
    def add_numbers(cls, a, b):
        return a + b

    # Static method
    @staticmethod
    def subtract_numbers(a, b):
        return a - b

# Example usage
print("Addition:", MathOperations.add_numbers(10, 5))     # 15
print("Subtraction:", MathOperations.subtract_numbers(10, 5))  # 5
# Out:
# Addition: 15
# Subtraction: 5

# %%
#8  Implement a class Person with a class method to count the total number of persons created.
class Person:
    # Class variable to keep track of total persons
    total_persons = 0

    def __init__(self, name):
        self.name = name
        # Increment count whenever a new object is created
        Person.total_persons += 1

    # Class method to get total persons created
    @classmethod
    def get_total_persons(cls):
        return cls.total_persons

# Example usage
p1 = Person("Alice")
p2 = Person("Bob")
p3 = Person("Charlie")

print("Total Persons Created:", Person.get_total_persons())
# Out:
# Total Persons Created: 3

# %%
#9 Write a class Fraction with attributes numerator and denominator. Override the str method to display the fraction as "numerator/denominator".
class Fraction:
    def __init__(self, numerator, denominator):
        self.numerator = numerator
        self.denominator = denominator

    # Override __str__ method
    def __str__(self):
        return f"{self.numerator}/{self.denominator}"

# Example usage
f1 = Fraction(3, 4)
f2 = Fraction(7, 2)

print(f1)  # Output: 3/4
print(f2)  # Output: 7/2
# Out:
# 3/4
# 7/2

# %%
#10  Demonstrate operator overloading by creating a class Vector and overriding the add method to add two vectors.
class Vector:
    def __init__(self, x, y):
        self.x = x
        self.y = y

    # Override the + operator
    def __add__(self, other):
        return Vector(self.x + other.x, self.y + other.y)

    # For printing nicely
    def __str__(self):
        return f"({self.x}, {self.y})"

# Example usage
v1 = Vector(2, 3)
v2 = Vector(4, 5)

v3 = v1 + v2   # Calls v1.__add__(v2)

print("v1 =", v1)  # (2, 3)
print("v2 =", v2)
# Out:
# v1 = (2, 3)
# v2 = (4, 5)

# %%
#11 Create a class Person with attributes name and age. Add a method greet() that prints "Hello, my name is {name} and I am {age} years old."
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def greet(self):
        print(f"Hello, my name is {self.name} and I am {self.age} years old.")

# Example usage
p1 = Person("Alice", 25)
p2 = Person("Bob", 30)

p1.greet()
p2.greet()
# Out:
# Hello, my name is Alice and I am 25 years old.
# Hello, my name is Bob and I am 30 years old.

# %%
#12 Implement a class Student with attributes name and grades. Create a method average_grade() to compute the average of the grades.
class Student:
    def __init__(self, name, grades):
        self.name = name
        self.grades = grades  # list of numbers

    def average_grade(self):
        if len(self.grades) == 0:
            return 0  # avoid division by zero
        return sum(self.grades) / len(self.grades)

# Example usage
s1 = Student("Alice", [85, 90, 78, 92])
s2 = Student("Bob", [70, 65, 80])

print(f"{s1.name}'s Average Grade: {s1.average_grade():.2f}")
print(f"{s2.name}'s Average Grade: {s2.average_grade():.2f}")
# Out:
# Alice's Average Grade: 86.25
# Bob's Average Grade: 71.67

# %%
#13  Create a class Rectangle with methods set_dimensions() to set the dimensions and area() to calculate the area.
class Rectangle:
    def __init__(self):
        self.length = 0
        self.width = 0

    # Method to set dimensions
    def set_dimensions(self, length, width):
        self.length = length
        self.width = width

    # Method to calculate area
    def area(self):
        return self.length * self.width

# Example usage
rect = Rectangle()
rect.set_dimensions(5, 10)

print("Area of Rectangle:", rect.area())
# Out:
# Area of Rectangle: 50

# %%
#14 Create a class Employee with a method calculate_salary() that computes the salary based on hours worked and hourly rate. Create a derived class Manager that adds a bonus to the salary.

# Base class
class Employee:
    def __init__(self, name, hours_worked, hourly_rate):
        self.name = name
        self.hours_worked = hours_worked
        self.hourly_rate = hourly_rate

    def calculate_salary(self):
        return self.hours_worked * self.hourly_rate


# Derived class
class Manager(Employee):
    def __init__(self, name, hours_worked, hourly_rate, bonus):
        super().__init__(name, hours_worked, hourly_rate)  # initialize parent attributes
        self.bonus = bonus

    # Override calculate_salary to include bonus
    def calculate_salary(self):
        base_salary = super().calculate_salary()
        return base_salary + self.bonus


# Example usage
emp = Employee("Alice", 40, 20)   # 40 hours, $20/hour
mgr = Manager("Bob", 40, 30, 500) # Manager with bonus

print(f"{emp.name}'s Salary: ${emp.calculate_salary()}")
print(f"{mgr.name}'s Salary: ${mgr.calculate_salary()}")
# Out:
# Alice's Salary: $800
# Bob's Salary: $1700

# %%
#15 Create a class Product with attributes name, price, and quantity. Implement a method total_price() that calculates the total price of the product.
class Product:
    def __init__(self, name, price, quantity):
        self.name = name
        self.price = price
        self.quantity = quantity

    # Method to calculate total price
    def total_price(self):
        return self.price * self.quantity

# Example usage
p1 = Product("Laptop", 50000, 2)
p2 = Product("Phone", 20000, 3)

print(f"{p1.name} Total Price: ₹{p1.total_price()}")
print(f"{p2.name} Total Price: ₹{p2.total_price()}")
# Out:
# Laptop Total Price: ₹100000
# Phone Total Price: ₹60000

# %%
#16  Create a class Animal with an abstract method sound(). Create two derived classes Cow and Sheep that implement the sound() method.
from abc import ABC, abstractmethod

# Abstract base class
class Animal(ABC):
    @abstractmethod
    def sound(self):
        pass  # must be implemented in child classes

# Derived class: Cow
class Cow(Animal):
    def sound(self):
        return "Moo"

# Derived class: Sheep
class Sheep(Animal):
    def sound(self):
        return "Baa"

# Example usage
animals = [Cow(), Sheep()]

for animal in animals:
    print(f"{animal.__class__.__name__} sound: {animal.sound()}")
# Out:
# Cow sound: Moo
# Sheep sound: Baa

# %%
#17 Create a class Book with attributes title, author, and year_published. Add a method get_book_info() that returns a formatted string with the book's details.
class Book:
    def __init__(self, title, author, year_published):
        self.title = title
        self.author = author
        self.year_published = year_published

    # Method to return formatted book info
    def get_book_info(self):
        return f"'{self.title}' by {self.author}, published in {self.year_published}"

# Example usage
b1 = Book("The Great Gatsby", "F. Scott Fitzgerald", 1925)
b2 = Book("To Kill a Mockingbird", "Harper Lee", 1960)

print(b1.get_book_info())
print(b2.get_book_info())
# Out:
# 'The Great Gatsby' by F. Scott Fitzgerald, published in 1925
# 'To Kill a Mockingbird' by Harper Lee, published in 1960

# %%
#18 Create a class House with attributes address and price. Create a derived class Mansion that adds an attribute number_of_rooms.
# Base class
class House:
    def __init__(self, address, price):
        self.address = address
        self.price = price

    def get_info(self):
        return f"House located at {self.address}, priced at ₹{self.price}"

# Derived class
class Mansion(House):
    def __init__(self, address, price, number_of_rooms):
        super().__init__(address, price)   # initialize parent attributes
        self.number_of_rooms = number_of_rooms

    def get_info(self):
        return f"Mansion at {self.address}, Price: ₹{self.price}, Rooms: {self.number_of_rooms}"

# Example usage
h1 = House("123 Green Street", 5000000)
m1 = Mansion("456 Royal Avenue", 20000000, 15)

print(h1.get_info())
print(m1.get_info())
# Out:
# House located at 123 Green Street, priced at ₹5000000
# Mansion at 456 Royal Avenue, Price: ₹20000000, Rooms: 15
